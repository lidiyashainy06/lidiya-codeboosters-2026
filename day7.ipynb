# %% [markdown]
# <a href="https://colab.research.google.com/github/lidiyashainy06/lidiya-codeboosters-2026/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  chromadb sentence-transformers -q
# 384 dimensional number vectors
#chromadb data base

# %%
# !pip install chromadb sentence-transformers -q


print("Installation complete ")
# Out:
# Installation complete

# %%
# !pip uninstall -y \
    chromadb sentence-transformers \
    opentelemetry-api opentelemetry-sdk opentelemetry-proto \
    opentelemetry-exporter-otlp-proto-grpc opentelemetry-exporter-otlp-proto-common \
    opentelemetry-exporter-otlp-proto-http \
    opentelemetry-instrumentation-fastapi opentelemetry-distro \
    opentelemetry-exporter-gcp-trace opentelemetry-exporter-gcp-monitoring \
    opentelemetry-exporter-gcp-logging \
    -q

# !pip install chromadb sentence-transformers -q

import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer

import chromadb
print("All libraries imported successfully !")
print(f"chromadb version : {chromadb.__version__}")
# Out:
# WARNING: Skipping opentelemetry-exporter-otlp-proto-http as it is not installed.
# WARNING: Skipping opentelemetry-instrumentation-fastapi as it is not installed.
# WARNING: Skipping opentelemetry-distro as it is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.29.0 requires opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0, which is not installed.
# google-adk 1.29.0 requires opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0, which is not installed.
# google-adk 1.29.0 requires opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0, which is not installed.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, which is not installed.
# google-adk 1.29.0 requires fastapi<1.0.0,>=0.124.1, but you have fastapi 0.85.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# google-adk 1.29.0 requires starlette<1.0.0,>=0.49.1, but you have starlette 0.20.4 which is incompatible.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_7506/3529824500.py in <cell line: 0>()
#       7 from sentence_transformers import SentenceTransformer
#       8
# ----> 9 import chromadb
#      10 print("All libraries imported successfully !")
#      11 print(f"chromadb version : {chromadb.__version__}")
#
# /usr/local/lib/python3.12/dist-packages/chromadb/__init__.py in <module>
#       9 )
#      10 from chromadb.api.async_client import AsyncClient as AsyncClientCreator
# ---> 11 from chromadb.auth.token_authn import TokenTransportHeader
#      12 import chromadb.config
#      13 from chromadb.config import DEFAULT_DATABASE, DEFAULT_TENANT, Settings
#
# /usr/local/lib/python3.12/dist-packages/chromadb/auth/token_authn/__init__.py in <module>
#      22 from chromadb.config import System
#      23 from chromadb.errors import ChromaAuthError
# ---> 24 from chromadb.telemetry.opentelemetry import (
#      25     OpenTelemetryGranularity,
#      26     trace_method,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/telemetry/opentelemetry/__init__.py in <module>
#      11     BatchSpanProcessor,
#      12 )
# ---> 13 from opentelemetry.exporter.otlp.proto.grpc.trace_exporter import OTLPSpanExporter
#      14
#      15 from chromadb.config import Component
#
# /usr/local/lib/python3.12/dist-packages/opentelemetry/exporter/otlp/proto/grpc/trace_exporter/__init__.py in <module>
#      13     encode_spans,
#      14 )
# ---> 15 from opentelemetry.exporter.otlp.proto.grpc.exporter import (  # noqa: F401
#      16     OTLPExporterMixin,
#      17     _get_credentials,
#
# /usr/local/lib/python3.12/dist-packages/opentelemetry/exporter/otlp/proto/grpc/exporter.py in <module>
#      81 from opentelemetry.proto.resource.v1.resource_pb2 import Resource  # noqa: F401
#      82 from opentelemetry.sdk._logs import ReadableLogRecord
# ---> 83 from opentelemetry.sdk._logs.export import LogRecordExportResult
#      84 from opentelemetry.sdk._shared_internal import DuplicateFilter
#      85 from opentelemetry.sdk.environment_variables import (
#
# /usr/local/lib/python3.12/dist-packages/opentelemetry/sdk/_logs/export/__init__.py in <module>
#       2 # SPDX-License-Identifier: Apache-2.0
#       3
# ----> 4 from opentelemetry.sdk._logs._internal.export import (
#       5     BatchLogRecordProcessor,
#       6     ConsoleLogExporter,
#
# /usr/local/lib/python3.12/dist-packages/opentelemetry/sdk/_logs/_internal/export/__init__.py in <module>
#      13 from typing_extensions import deprecated
#      14
# ---> 15 from opentelemetry.context import (
#      16     _ON_EMIT_RECURSION_COUNT_KEY,
#      17     _SUPPRESS_INSTRUMENTATION_KEY,
#
# ImportError: cannot import name '_ON_EMIT_RECURSION_COUNT_KEY' from 'opentelemetry.context' (/usr/local/lib/python3.12/dist-packages/opentelemetry/context/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
documents = [
    "ETL is used to clean and transform data ",           #doc_0
    "A vehicle is a  mode of transporation ",
    "cars and trucks are popular automobiles ",
    "SQL is used to query database ",
    "Machine learning trains models on data ",

]

query_keyword = "vehicle "

print("="* 60)
print(f"KEYWORD SEARCH for : '{query_keyword }' ")
print("="* 60)
for i , doc in enumerate (documents):
    if query_keyword.lower() in doc.lower():
        print(f'FOUND  [doc_{i}] : {doc}')
    else:
        print(f'MISSED [doc_{i}] : {doc}')



print()
print("PROBLEM : doc_2 talks about 'Cars and trucks' - which are vehicles!")
print("But keyword search missed it because it only checks for 'vehicle'")
# Out:
# ============================================================
# KEYWORD SEARCH for : 'vehicle '
# ============================================================
# MISSED [doc_0] : ETL is used to clean and transform data
# FOUND  [doc_1] : A vehicle is a  mode of transporation
# MISSED [doc_2] : cars and trucks are popular automobiles
# MISSED [doc_3] : SQL is used to query database
# MISSED [doc_4] : Machine learning trains models on data
#
# PROBLEM : doc_2 talks about 'Cars and trucks' - which are vehicles!
# But keyword search missed it because it only checks for 'vehicle'

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

print("model loaded successfully!")
print(f" Model produce vector size : {model.get_sentence_embedding_dimension()}")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# model loaded successfully!
#  Model produce vector size : 384
# /tmp/ipykernel_7197/3926738868.py:4: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   print(f" Model produce vector size : {model.get_sentence_embedding_dimension()}")

# %%
sentence = "ETL is used to clean data "

embedding = model.encode(sentence)
print(f" input sentence : {sentence}")
print(f" embedding shape : '{embedding.shape}'")
print()
print(f"Embedding type: {type(embedding)}")
print(f"Embedding shape :{embedding.shape}")
print(f"First 10 numbers :{embedding[:10].round(4)}")


print(f"Min value :{embedding.min ():.4f}")
print(f"Max value :{embedding.max ():.4f}")
# Out:
#  input sentence : ETL is used to clean data
#  embedding shape : '(384,)'
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape :(384,)
# First 10 numbers :[-0.0555  0.0501  0.0355 -0.0242  0.0389 -0.1049  0.0364 -0.0279  0.0727
#   0.0302]
# Min value :-0.1245
# Max value :0.1905

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
sentences = [
    "ETL is used to clean and tranform the data",   #sentence 1
    "A vehicle is a mode of transportation",        #sentence 2
    "The sky is blue and clouds are white"          #sentence 3
]
embedding = model.encode(sentences)

print(f"Number of sentences: {len(sentences)}")
print(f"Embedding shape : {embedding.shape}")

print()
print("Each row is one sentence's embeddings : ")
for i, sent in enumerate(sentences):
  print(f"Sentences {i} : shape(embeddings[i].shape), first 5 values : {embedding[i][:5]}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Number of sentences: 3
# Embedding shape : (3, 384)
#
# Each row is one sentence's embeddings :
# Sentences 0 : shape(embeddings[i].shape), first 5 values : [-0.05787504  0.03791896  0.00393011 -0.02855824  0.02375512]
# Sentences 1 : shape(embeddings[i].shape), first 5 values : [-0.00496492 -0.00667225  0.00681395  0.04137361 -0.00743163]
# Sentences 2 : shape(embeddings[i].shape), first 5 values : [0.05435543 0.05999928 0.07466635 0.04920832 0.05014358]

# %%
import chromadb
chroma_client = chromadb.Client()
collection = chroma_client.get_or_create_collection('demo_notes')

sample_docs = [
    "ETL is used to clean and transform data",
    "A vehicle is a mode of transportation",
    "Cars and trucks are popular automobiles",
    "SQL is used to query databases",
    "Machine learning trains models on data"
]

sample_ids = ['doc001', 'doc002', 'doc003', 'doc004', 'doc005']

sample_metadata = [
    {"subject": "Data Engineering", "topic": "ETL"},
    {"subject": "Data Engineering", "topic": "SQL"},
    {"subject": "Machine Learning", "topic": "ML Basic"},
    {"subject": "Python", "topic": "Pandas"},
    {"subject": "Machine Learning", "topic": "Neural Networks"}
]

sample_embeddings = model.encode(sample_docs).tolist()

collection.add (
    documents=sample_docs,
    embeddings=sample_embeddings,
    ids=sample_ids,
    metadatas=sample_metadata
)

print("Documents added successfully")
print(f"Number of documents in collection: {collection.count()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7506/3415416379.py in <cell line: 0>()
#      19 sample_embeddings = model.encode(sample_docs).tolist()
#      20
# ---> 21 collection.add (
#      22     documents=sample_docs,
#      23     embeddings=sample_embeddings,
#
# NameError: name 'collection' is not defined

# %%
# !pip install chromadb -q
import chromadb
client = chromadb.EphemeralClient()

notes_collection = client.create_collection(name="college_notes")

print("Chromadb collection 'collge_notes' created successfully!")
print(f"Documents in collection : {notes_collection.count()}")
# Out:
# Chromadb collection 'collge_notes' created successfully!
# Documents in collection : 0
